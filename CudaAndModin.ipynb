# %%
import cudf  # this should work without any errors

# %%
# !pip install plotly-express
# Out:
# Collecting plotly-express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: pandas>=0.20.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from plotly-express) (1.5.3)
# Collecting plotly>=4.1.0 (from plotly-express)
#   Downloading plotly-5.18.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting statsmodels>=0.9.0 (from plotly-express)
#   Downloading statsmodels-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 15.5 MB/s eta 0:00:00m eta 0:00:01:01:01
# Collecting scipy>=0.18 (from plotly-express)
#   Downloading scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 5.3 MB/s eta 0:00:00
# Collecting patsy>=0.5 (from plotly-express)
#   Downloading patsy-0.5.4-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.11 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from plotly-express) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from pandas>=0.20.0->plotly-express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from pandas>=0.20.0->plotly-express) (2023.3.post1)
# Requirement already satisfied: six in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from patsy>=0.5->plotly-express) (1.16.0)
# Collecting tenacity>=6.2.0 (from plotly>=4.1.0->plotly-express)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: packaging in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from plotly>=4.1.0->plotly-express) (23.2)
# Downloading patsy-0.5.4-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 8.7 MB/s eta 0:00:00
# Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 27.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 29.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, scipy, patsy, plotly, statsmodels, plotly-express
# Successfully installed patsy-0.5.4 plotly-5.18.0 plotly-express-0.4.1 scipy-1.11.4 statsmodels-0.14.0 tenacity-8.2.3

# %%
# !wget https://data.rapids.ai/datasets/nyc_parking/nyc_parking_violations_2022.parquet
# Out:
# --2023-12-13 20:25:11--  https://data.rapids.ai/datasets/nyc_parking/nyc_parking_violations_2022.parquet
# Resolving data.rapids.ai (data.rapids.ai)... 2600:9000:2335:9a00:1a:8fa4:1000:93a1, 2600:9000:2335:ba00:1a:8fa4:1000:93a1, 2600:9000:2335:aa00:1a:8fa4:1000:93a1, ...
# Connecting to data.rapids.ai (data.rapids.ai)|2600:9000:2335:9a00:1a:8fa4:1000:93a1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 477161608 (455M) [binary/octet-stream]
# Saving to: ‘nyc_parking_violations_2022.parquet’
#
# nyc_parking_violati 100%[===================>] 455.06M  29.5MB/s    in 16s
#
# 2023-12-13 20:25:29 (27.7 MB/s) - ‘nyc_parking_violations_2022.parquet’ saved [477161608/477161608]

# %%
import pandas as pd

# %%
# read 5 columns data:
df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=["Registration State", "Violation Description", "Vehicle Body Type", "Issue Date", "Summons Number"]
)

# view a random sample of 10 rows:
df.sample(10)
# Out:
#          Registration State           Violation Description Vehicle Body Type  \
# 14272412                 NY    21-No Parking (street clean)              SUBN
# 5169487                  NY  70A-Reg. Sticker Expired (NYS)              FLAT
# 9512266                  NY  PHTO SCHOOL ZN SPEED VIOLATION              SUBN
# 15059277                 NJ  38-Failure to Dsplay Meter Rec              SUBN
# 3162659                  NY          19-No Stand (bus stop)              SUBN
# 1353666                  NY    21-No Parking (street clean)              SUBN
# 5822362                  PA              BUS LANE VIOLATION                SW
# 10492509                 NY  PHTO SCHOOL ZN SPEED VIOLATION              SUBN
# 7276711                  MS  PHTO SCHOOL ZN SPEED VIOLATION                UV
# 10518714                 TN  PHTO SCHOOL ZN SPEED VIOLATION              <NA>
#
#           Issue Date  Summons Number
# 14272412  05/27/2022      8810296448
# 5169487   10/04/2021      8943474751
# 9512266   02/10/2022      4767541402
# 15059277  06/03/2022      8866224339
# 3162659   09/07/2021      8966758228
# 1353666   06/30/2021      8989415111
# 5822362   10/30/2021      4020526412
# 10492509  02/23/2022      4769695391
# 7276711   12/16/2021      4760841556
# 10518714  03/04/2022      4770731644

# %%
(df[["Registration State", "Violation Description"]]  # get only these two columns
 .value_counts()  # get the count of offences per state and per type of offence
 .groupby("Registration State")  # group by state
 .head(1)  # get the first row in each group (the type of offence with the largest count)
 .sort_index()  # sort by state name
 .reset_index()
)
# Out:
#    Registration State           Violation Description     0
# 0                  99        74-Missing Display Plate   835
# 1                  AB                  14-No Standing    22
# 2                  AK  PHTO SCHOOL ZN SPEED VIOLATION   125
# 3                  AL  PHTO SCHOOL ZN SPEED VIOLATION  3668
# 4                  AR  PHTO SCHOOL ZN SPEED VIOLATION   537
# ..                ...                             ...   ...
# 60                 VT  PHTO SCHOOL ZN SPEED VIOLATION  3024
# 61                 WA    21-No Parking (street clean)  3732
# 62                 WI                  14-No Standing  1639
# 63                 WV  PHTO SCHOOL ZN SPEED VIOLATION  1185
# 64                 WY    21-No Parking (street clean)   138
#
# [65 rows x 3 columns]

# %%
(df
 .groupby(["Vehicle Body Type"])
 .agg({"Summons Number": "count"})
 .rename(columns={"Summons Number": "Count"})
 .sort_values(["Count"], ascending=False)
)
# Out:
#                      Count
# Vehicle Body Type
# SUBN               6449007
# 4DSD               4402991
# VAN                1317899
# DELV                436430
# PICK                429798
# ...                    ...
# CARY                     1
# ISUZ                     1
# IXMR                     1
# BILB                     1
# ONEL                     1
#
# [966 rows x 1 columns]

# %%
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64

# %%
# %%time

df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=["Registration State", "Violation Description", "Vehicle Body Type", "Issue Date", "Summons Number"]
)

(df[["Registration State", "Violation Description"]]
 .value_counts()
 .groupby("Registration State")
 .head(1)
 .sort_index()
 .reset_index()
)
# Out:
# CPU times: user 6.92 s, sys: 2.62 s, total: 9.54 s
# Wall time: 6.4 s
#    Registration State           Violation Description     0
# 0                  99        74-Missing Display Plate   835
# 1                  AB                  14-No Standing    22
# 2                  AK  PHTO SCHOOL ZN SPEED VIOLATION   125
# 3                  AL  PHTO SCHOOL ZN SPEED VIOLATION  3668
# 4                  AR  PHTO SCHOOL ZN SPEED VIOLATION   537
# ..                ...                             ...   ...
# 60                 VT  PHTO SCHOOL ZN SPEED VIOLATION  3024
# 61                 WA    21-No Parking (street clean)  3732
# 62                 WI                  14-No Standing  1639
# 63                 WV  PHTO SCHOOL ZN SPEED VIOLATION  1185
# 64                 WY    21-No Parking (street clean)   138
#
# [65 rows x 3 columns]

# %%
# %%time

(df
 .groupby(["Vehicle Body Type"])
 .agg({"Summons Number": "count"})
 .rename(columns={"Summons Number": "Count"})
 .sort_values(["Count"], ascending=False)
)
# Out:
# CPU times: user 1.47 s, sys: 80.7 ms, total: 1.55 s
# Wall time: 1.55 s
#                      Count
# Vehicle Body Type
# SUBN               6449007
# 4DSD               4402991
# VAN                1317899
# DELV                436430
# PICK                429798
# ...                    ...
# CARY                     1
# ISUZ                     1
# IXMR                     1
# BILB                     1
# ONEL                     1
#
# [966 rows x 1 columns]

# %%
# %%time

weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# CPU times: user 2.94 s, sys: 426 ms, total: 3.36 s
# Wall time: 3.37 s
# issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64

# %%
get_ipython().kernel.do_shutdown(restart=True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
# %load_ext cudf.pandas
# Out:
# The cudf.pandas extension is already loaded. To reload it, use:
#   %reload_ext cudf.pandas

# %%
# %%time

import pandas as pd

df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=["Registration State", "Violation Description", "Vehicle Body Type", "Issue Date", "Summons Number"]
)

(df[["Registration State", "Violation Description"]]
 .value_counts()
 .groupby("Registration State")
 .head(1)
 .sort_index()
 .reset_index()
)
# Out:
# CPU times: user 8.57 s, sys: 2.85 s, total: 11.4 s
# Wall time: 8.23 s
#    Registration State           Violation Description     0
# 0                  99        74-Missing Display Plate   835
# 1                  AB                  14-No Standing    22
# 2                  AK  PHTO SCHOOL ZN SPEED VIOLATION   125
# 3                  AL  PHTO SCHOOL ZN SPEED VIOLATION  3668
# 4                  AR  PHTO SCHOOL ZN SPEED VIOLATION   537
# ..                ...                             ...   ...
# 60                 VT  PHTO SCHOOL ZN SPEED VIOLATION  3024
# 61                 WA    21-No Parking (street clean)  3732
# 62                 WI                  14-No Standing  1639
# 63                 WV  PHTO SCHOOL ZN SPEED VIOLATION  1185
# 64                 WY    21-No Parking (street clean)   138
#
# [65 rows x 3 columns]

# %%
# %%time

import pandas as pd

df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=["Registration State", "Violation Description", "Vehicle Body Type", "Issue Date", "Summons Number"]
)

(df[["Registration State", "Violation Description"]]
 .value_counts()
 .groupby("Registration State")
 .head(1)
 .sort_index()
 .reset_index()
)
# Out:
# CPU times: user 8.57 s, sys: 2.85 s, total: 11.4 s
# Wall time: 8.23 s
#    Registration State           Violation Description     0
# 0                  99        74-Missing Display Plate   835
# 1                  AB                  14-No Standing    22
# 2                  AK  PHTO SCHOOL ZN SPEED VIOLATION   125
# 3                  AL  PHTO SCHOOL ZN SPEED VIOLATION  3668
# 4                  AR  PHTO SCHOOL ZN SPEED VIOLATION   537
# ..                ...                             ...   ...
# 60                 VT  PHTO SCHOOL ZN SPEED VIOLATION  3024
# 61                 WA    21-No Parking (street clean)  3732
# 62                 WI                  14-No Standing  1639
# 63                 WV  PHTO SCHOOL ZN SPEED VIOLATION  1185
# 64                 WY    21-No Parking (street clean)   138
#
# [65 rows x 3 columns]

# %%
# %%time

weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# CPU times: user 7.29 s, sys: 1.31 s, total: 8.59 s
# Wall time: 8.49 s
# issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64

# %%
# %%cudf.pandas.profile
#
# small_df = pd.DataFrame({'a': [0, 1, 2], 'b': ["x", "y", "z"]})
# small_df = pd.concat([small_df, small_df])
#
# axis = 0
# for i in range(0, 2):
#     small_df.min(axis=axis)
#     axis = 1
#
# counts = small_df.groupby("a").b.count()
# Out:
# /home/soap1196/miniconda3/envs/rapids-23.12/lib/python3.10/site-packages/cudf/core/dataframe.py:5933: UserWarning: Row-wise operations currently only support int, float and bool dtypes. Non numeric columns are ignored.
#   warnings.warn(msg)
# ../../thread/thread_load.cuh(36): warning: cuda.h: [jitify] File not found
# ../../thread/thread_store.cuh(36): warning: cuda.h: [jitify] File not found
#
#                                         Total time elapsed: 6.623 seconds
#                                       5 GPU function calls in 6.280 seconds
#                                       1 CPU function calls in 0.012 seconds
#
#                                                       Stats
#
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Function            ┃ GPU ncalls ┃ GPU cumtime ┃ GPU percall ┃ CPU ncalls ┃ CPU cumtime ┃ CPU percall ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ DataFrame           │ 1          │ 0.017       │ 0.017       │ 0          │ 0.000       │ 0.000       │
# │ concat              │ 1          │ 0.017       │ 0.017       │ 0          │ 0.000       │ 0.000       │
# │ DataFrame.min       │ 1          │ 6.235       │ 6.235       │ 1          │ 0.012       │ 0.012       │
# │ DataFrame.groupby   │ 1          │ 0.000       │ 0.000       │ 0          │ 0.000       │ 0.000       │
# │ SeriesGroupBy.count │ 1          │ 0.011       │ 0.011       │ 0          │ 0.000       │ 0.000       │
# └─────────────────────┴────────────┴─────────────┴─────────────┴────────────┴─────────────┴─────────────┘
# Not all pandas operations ran on the GPU. The following functions required CPU fallback:
#
# - DataFrame.min
# To request GPU support for any of these functions, please file a Github issue here:
# ]8;id=777675;https://github.com/rapidsai/cudf/issues/new?assignees=&labels=%3F+-+Needs+Triage%2C+feature+request&projects=&template=pandas_function_request.md&title=%5BFEA%5D\https://github.com/rapidsai/cudf/issues/new/choose]8;;\.

# %%
get_ipython().kernel.do_shutdown(restart=True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
# !pip install "modin[all]"
# Out:
# Collecting modin[all]
#   Using cached modin-0.25.1-py3-none-any.whl.metadata (17 kB)
# Collecting pandas<2.2,>=2.1 (from modin[all])
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: packaging>=21.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from modin[all]) (23.2)
# Requirement already satisfied: numpy>=1.22.4 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from modin[all]) (1.24.4)
# Requirement already satisfied: fsspec>=2022.05.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from modin[all]) (2023.12.2)
# Requirement already satisfied: psutil>=5.8.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from modin[all]) (5.9.6)
# Collecting dask>=2.22.0 (from modin[all])
#   Using cached dask-2023.12.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting distributed>=2.22.0 (from modin[all])
#   Using cached distributed-2023.12.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ray!=2.5.0,>=1.13.0 (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Downloading ray-2.8.1-cp310-cp310-manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: pyarrow>=7.0.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from modin[all]) (14.0.1)
# Collecting pydantic<2 (from modin[all])
#   Downloading pydantic-1.10.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 2.2 MB/s eta 0:00:001.2 MB/s eta 0:00:01
# Collecting unidist<=0.4.1,>=0.2.1 (from unidist[mpi]<=0.4.1,>=0.2.1; extra == "all"->modin[all])
#   Using cached unidist-0.4.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting modin-spreadsheet>=0.1.0 (from modin[all])
#   Using cached modin_spreadsheet-0.1.2-py2.py3-none-any.whl (1.8 MB)
# Collecting click>=8.1 (from dask>=2.22.0->modin[all])
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle>=1.5.0 (from dask>=2.22.0->modin[all])
#   Using cached cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting partd>=1.2.0 (from dask>=2.22.0->modin[all])
#   Using cached partd-1.4.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from dask>=2.22.0->modin[all]) (6.0.1)
# Collecting toolz>=0.10.0 (from dask>=2.22.0->modin[all])
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting importlib-metadata>=4.13.0 (from dask>=2.22.0->modin[all])
#   Using cached importlib_metadata-7.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jinja2>=2.10.3 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from distributed>=2.22.0->modin[all]) (3.1.2)
# Collecting locket>=1.0.0 (from distributed>=2.22.0->modin[all])
#   Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msgpack>=1.0.0 (from distributed>=2.22.0->modin[all])
#   Downloading msgpack-1.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting sortedcontainers>=2.0.5 (from distributed>=2.22.0->modin[all])
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting tblib>=1.6.0 (from distributed>=2.22.0->modin[all])
#   Using cached tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tornado>=6.0.4 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from distributed>=2.22.0->modin[all]) (6.4)
# Requirement already satisfied: urllib3>=1.24.3 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from distributed>=2.22.0->modin[all]) (2.1.0)
# Collecting zict>=3.0.0 (from distributed>=2.22.0->modin[all])
#   Using cached zict-3.0.0-py2.py3-none-any.whl (43 kB)
# Collecting jupyter>=1.0.0 (from modin-spreadsheet>=0.1.0->modin[all])
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting notebook>=6.0.3 (from modin-spreadsheet>=0.1.0->modin[all])
#   Using cached notebook-7.0.6-py3-none-any.whl.metadata (10 kB)
# Collecting ipywidgets>=7.0.0 (from modin-spreadsheet>=0.1.0->modin[all])
#   Using cached ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from pandas<2.2,>=2.1->modin[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from pandas<2.2,>=2.1->modin[all]) (2023.3.post1)
# Collecting tzdata>=2022.1 (from pandas<2.2,>=2.1->modin[all])
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from pydantic<2->modin[all]) (4.9.0)
# Collecting filelock (from ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: jsonschema in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (4.20.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (4.24.4)
# Collecting aiosignal (from ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist (from ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Downloading frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: requests in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (2.31.0)
# Collecting aiohttp>=3.7 (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Downloading aiohttp-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting aiohttp-cors (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting colorful (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached colorful-0.5.5-py2.py3-none-any.whl (201 kB)
# Collecting py-spy>=0.2.0 (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# Collecting gpustat>=1.0.0 (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Downloading gpustat-1.1.1.tar.gz (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting opencensus (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached opencensus-0.11.3-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (0.19.0)
# Collecting smart-open (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv<20.21.1,>=20.0.24 (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
# Collecting grpcio>=1.42.0 (from ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Downloading grpcio-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting mpi4py-mpich (from unidist[mpi]<=0.4.1,>=0.2.1; extra == "all"->modin[all])
#   Downloading mpi4py_mpich-3.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 5.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: attrs>=17.3.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from aiohttp>=3.7->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.7->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 4.1 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.7->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp>=3.7->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting nvidia-ml-py>=11.450.129 (from gpustat>=1.0.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached nvidia_ml_py-12.535.133-py3-none-any.whl.metadata (8.6 kB)
# Collecting blessed>=1.17.1 (from gpustat>=1.0.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached blessed-1.20.0-py2.py3-none-any.whl (58 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=4.13.0->dask>=2.22.0->modin[all])
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: comm>=0.1.3 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.14.0)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all])
#   Using cached widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.9 (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all])
#   Using cached jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jinja2>=2.10.3->distributed>=2.22.0->modin[all]) (2.1.3)
# Collecting qtconsole (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all])
#   Using cached qtconsole-5.5.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all])
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: nbconvert in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (7.12.0)
# Requirement already satisfied: ipykernel in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.27.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.12.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.2.3)
# Requirement already satisfied: six>=1.5 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<2.2,>=2.1->modin[all]) (1.16.0)
# Collecting distlib<1,>=0.3.6 (from virtualenv<20.21.1,>=20.0.24->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached distlib-0.3.8-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting platformdirs<4,>=2.4 (from virtualenv<20.21.1,>=20.0.24->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached platformdirs-3.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jsonschema->ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jsonschema->ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jsonschema->ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (0.13.2)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached google_api_core-2.15.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from requests->ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from requests->ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from requests->ray!=2.5.0,>=1.13.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (2023.11.17)
# Requirement already satisfied: wcwidth>=0.1.4 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (0.2.12)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached google_auth-2.25.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: decorator in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.17.2)
# Requirement already satisfied: stack-data in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.6.3)
# Requirement already satisfied: exceptiongroup in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.9.0)
# Requirement already satisfied: anyio>=3.1.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (4.1.0)
# Requirement already satisfied: argon2-cffi in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (5.5.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.5.0)
# Requirement already satisfied: nbformat>=5.3.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (5.9.2)
# Requirement already satisfied: overrides in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (7.4.0)
# Requirement already satisfied: pyzmq>=24 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.18.0)
# Requirement already satisfied: websocket-client in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.2.1)
# Requirement already satisfied: tomli in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.0.1)
# Requirement already satisfied: babel>=2.10 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.9.14)
# Requirement already satisfied: beautifulsoup4 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.1.0)
# Requirement already satisfied: defusedxml in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.5.0)
# Requirement already satisfied: tinycss2 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.8.0)
# Requirement already satisfied: nest-asyncio in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.5.8)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all])
#   Using cached QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sniffio>=1.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.3.0)
# Requirement already satisfied: webencodings in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.5.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all]) (5.3.2)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.1.1)
# Requirement already satisfied: fastjsonschema in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.19.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.5)
# Requirement already satisfied: executing>=1.2.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.4.1)
# Requirement already satisfied: pure-eval in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.2)
# Requirement already satisfied: fqdn in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.5.1)
# Requirement already satisfied: isoduration in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.4)
# Requirement already satisfied: uri-template in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.13)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]!=2.5.0,>=1.13.0; extra == "all"->modin[all])
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.16.0)
# Requirement already satisfied: pycparser in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./miniconda3/envs/rapids-23.12/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.8.19.14)
# Using cached dask-2023.12.0-py3-none-any.whl (1.2 MB)
# Using cached distributed-2023.12.0-py3-none-any.whl (997 kB)
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 6.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading pydantic-1.10.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 7.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading ray-2.8.1-cp310-cp310-manylinux2014_x86_64.whl (62.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 MB 10.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading unidist-0.4.1-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.4/108.4 kB 7.4 MB/s eta 0:00:00
# Downloading modin-0.25.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading aiohttp-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 9.6 MB/s eta 0:00:00
# Downloading grpcio-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 11.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Using cached ipywidgets-8.1.1-py3-none-any.whl (139 kB)
# Downloading msgpack-1.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (530 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.8/530.8 kB 11.1 MB/s eta 0:00:0031m13.8 MB/s eta 0:00:01
# Using cached notebook-7.0.6-py3-none-any.whl (4.0 MB)
# Using cached partd-1.4.1-py3-none-any.whl (18 kB)
# Using cached tblib-3.0.0-py3-none-any.whl (12 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached opencensus-0.11.3-py2.py3-none-any.whl (128 kB)
# Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached distlib-0.3.8-py2.py3-none-any.whl (468 kB)
# Using cached google_api_core-2.15.0-py3-none-any.whl (121 kB)
# Using cached jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
# Using cached nvidia_ml_py-12.535.133-py3-none-any.whl (37 kB)
# Using cached platformdirs-3.11.0-py3-none-any.whl (17 kB)
# Using cached widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
# Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 10.9 MB/s eta 0:00:00
# Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Using cached qtconsole-5.5.1-py3-none-any.whl (123 kB)
# Using cached google_auth-2.25.2-py2.py3-none-any.whl (184 kB)
# Using cached googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
# Using cached QtPy-2.4.1-py3-none-any.whl (93 kB)
# Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Building wheels for collected packages: gpustat
#   Building wheel for gpustat (pyproject.toml) ... done
#   Created wheel for gpustat: filename=gpustat-1.1.1-py3-none-any.whl size=26535 sha256=a10e7e6570d475f8e85aba077a9a5e51ee0d56135f7f5cfa6cd823b261684685
#   Stored in directory: /home/soap1196/.cache/pip/wheels/ec/d7/80/a71ba3540900e1f276bcae685efd8e590c810d2108b95f1e47
# Successfully built gpustat
# Installing collected packages: sortedcontainers, py-spy, opencensus-context, nvidia-ml-py, distlib, colorful, zipp, zict, widgetsnbextension, tzdata, toolz, tblib, smart-open, qtpy, pydantic, pyasn1, platformdirs, multidict, msgpack, mpi4py-mpich, locket, jupyterlab-widgets, grpcio, googleapis-common-protos, frozenlist, filelock, cloudpickle, click, blessed, async-timeout, yarl, virtualenv, unidist, rsa, pyasn1-modules, partd, pandas, importlib-metadata, gpustat, aiosignal, modin, google-auth, dask, aiohttp, ray, ipywidgets, google-api-core, distributed, aiohttp-cors, qtconsole, opencensus, jupyter-console, notebook, jupyter, modin-spreadsheet
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.1.0
#     Uninstalling platformdirs-4.1.0:
#       Successfully uninstalled platformdirs-4.1.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.12.1 requires cubinlinker, which is not installed.
# cudf 23.12.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.12.1 requires ptxcompiler, which is not installed.
# cudf 23.12.1 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.0.0 which is incompatible.
# cudf 23.12.1 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# Successfully installed aiohttp-3.9.1 aiohttp-cors-0.7.0 aiosignal-1.3.1 async-timeout-4.0.3 blessed-1.20.0 click-8.1.7 cloudpickle-3.0.0 colorful-0.5.5 dask-2023.12.0 distlib-0.3.8 distributed-2023.12.0 filelock-3.13.1 frozenlist-1.4.0 google-api-core-2.15.0 google-auth-2.25.2 googleapis-common-protos-1.62.0 gpustat-1.1.1 grpcio-1.60.0 importlib-metadata-7.0.0 ipywidgets-8.1.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyterlab-widgets-3.0.9 locket-1.0.0 modin-0.25.1 modin-spreadsheet-0.1.2 mpi4py-mpich-3.1.2 msgpack-1.0.7 multidict-6.0.4 notebook-7.0.6 nvidia-ml-py-12.535.133 opencensus-0.11.3 opencensus-context-0.1.3 pandas-2.1.4 partd-1.4.1 platformdirs-3.11.0 py-spy-0.3.14 pyasn1-0.5.1 pyasn1-modules-0.3.0 pydantic-1.10.13 qtconsole-5.5.1 qtpy-2.4.1 ray-2.8.1 rsa-4.9 smart-open-6.4.0 sortedcontainers-2.4.0 tblib-3.0.0 toolz-0.12.0 tzdata-2023.3 unidist-0.4.1 virtualenv-20.21.0 widgetsnbextension-4.0.9 yarl-1.9.4 zict-3.0.0 zipp-3.17.0

# %%
import modin.pandas as pd

# %%
import modin.pandas as pd

# %%
# %%time

import pandas as pd

df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=["Registration State", "Violation Description", "Vehicle Body Type", "Issue Date", "Summons Number"]
)

(df[["Registration State", "Violation Description"]]
 .value_counts()
 .groupby("Registration State")
 .head(1)
 .sort_index()
 .reset_index()
)
# Out:
# CPU times: user 6.49 s, sys: 2.54 s, total: 9.03 s
# Wall time: 5.87 s
#    Registration State           Violation Description  count
# 0                  99        74-Missing Display Plate    835
# 1                  AB                  14-No Standing     22
# 2                  AK  PHTO SCHOOL ZN SPEED VIOLATION    125
# 3                  AL  PHTO SCHOOL ZN SPEED VIOLATION   3668
# 4                  AR  PHTO SCHOOL ZN SPEED VIOLATION    537
# ..                ...                             ...    ...
# 60                 VT  PHTO SCHOOL ZN SPEED VIOLATION   3024
# 61                 WA    21-No Parking (street clean)   3732
# 62                 WI                  14-No Standing   1639
# 63                 WV  PHTO SCHOOL ZN SPEED VIOLATION   1185
# 64                 WY    21-No Parking (street clean)    138
#
# [65 rows x 3 columns]

# %%
# %%time

import pandas as pd

df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=["Registration State", "Violation Description", "Vehicle Body Type", "Issue Date", "Summons Number"]
)

(df[["Registration State", "Violation Description"]]
 .value_counts()
 .groupby("Registration State")
 .head(1)
 .sort_index()
 .reset_index()
)
# Out:
# CPU times: user 6.61 s, sys: 2.69 s, total: 9.3 s
# Wall time: 6.26 s
#    Registration State           Violation Description  count
# 0                  99        74-Missing Display Plate    835
# 1                  AB                  14-No Standing     22
# 2                  AK  PHTO SCHOOL ZN SPEED VIOLATION    125
# 3                  AL  PHTO SCHOOL ZN SPEED VIOLATION   3668
# 4                  AR  PHTO SCHOOL ZN SPEED VIOLATION    537
# ..                ...                             ...    ...
# 60                 VT  PHTO SCHOOL ZN SPEED VIOLATION   3024
# 61                 WA    21-No Parking (street clean)   3732
# 62                 WI                  14-No Standing   1639
# 63                 WV  PHTO SCHOOL ZN SPEED VIOLATION   1185
# 64                 WY    21-No Parking (street clean)    138
#
# [65 rows x 3 columns]

# %%
# %%time

weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# CPU times: user 1.73 s, sys: 356 ms, total: 2.08 s
# Wall time: 2.09 s
# issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64
